# %%
# %load app.py
import numpy as np
import pandas as pd

class CSVer:

    def __init__(self, file_name, nrows = None):
        self.csv = pd.read_csv(file_name, nrows = nrows)

    def get_first_n_rows(self, n):
        return  self.csv.head(n)

    def get_column(self, column_name):
        return self.csv[column_name]

    def get_distinct_rows(self, column_name):
        distinct_rows = self.get_column(column_name).unique()
        return distinct_rows

    def filter_column_by_value(self, column, value):
        return self.csv.loc[self.csv[column] == value]

name = 'solicitado_small.csv'
n = 1000
csver = CSVer(file_name = name, nrows = n)
csv = csver.csv
csv
# Out:
#                                                   Item  \
# 0                                            Camareira
# 1                           Hospedagem sem Alimentação
# 2                                            Camareira
# 3                                            Camareira
# 4                                            Camareira
# 5                                            Camareira
# 6                                            Camareira
# 7                                 Passagens terrestres
# 8                                               Cartaz
# 9      Locação de equipamentos (para sala de imprensa)
# 10                                                INSS
# 11                                            Telefone
# 12                          Locação de mesa e refletor
# 13                                           Maquiador
# 14                                Passagens terrestres
# 15                                              Cartaz
# 16                                            Telefone
# 17                                           Camareira
# 18                                              Cartaz
# 19                                             Tiragem
# 20                    Produção de Imagem (audiovisual)
# 21                                              Cartaz
# 22                                            Telefone
# 23                                                INSS
# 24                                           Maquiador
# 25                                         Cenotécnico
# 26                          Locação de mesa e refletor
# 27                                           Camareira
# 28                          Locação de mesa e refletor
# 29                                            Telefone
# ..                                                 ...
# 940                                   Veículos de cena
# 941                         Hospedagem sem Alimentação
# 942                                           Refeição
# 943                                           Telefone
# 944                                           Telefone
# 945                                        Combustível
# 946                                      Pacote música
# 947                                             Cartaz
# 948                                           Refeição
# 949                                               INSS
# 950                                           Refeição
# 951                               Passagens terrestres
# 952                         Hospedagem sem Alimentação
# 953                                           Refeição
# 954                                           Telefone
# 955                                          Segurança
# 956                            Locação de computadores
# 957                               Locação de auditório
# 958                                               INSS
# 959  Seguro (pessoas, obras e equipamentos - especi...
# 960                           Distribuidor de impresso
# 961                                   Frete rodoviário
# 962                                        Frete aéreo
# 963                                            Curador
# 964                             Assistente de produção
# 965                   Companhias e/ou escolas de Dança
# 966                                            Curador
# 967                             Assistente de produção
# 968                                        Eletricista
# 969                                       Contra-regra
#
#      ValorUnitarioSolicitado                 Data  IdPRONAC
# 0                     1600.0  2009-04-06 00:00:00    111221
# 1                      150.0  2009-04-06 00:00:00    111221
# 2                      500.0  2009-05-01 00:00:00    111211
# 3                      500.0  2009-05-01 00:00:00    111211
# 4                      500.0  2009-05-01 00:00:00    111211
# 5                      500.0  2009-05-01 00:00:00    111211
# 6                      625.0  2009-05-01 00:00:00    111211
# 7                      150.0  2009-05-01 00:00:00    111211
# 8                        2.5  2009-05-01 00:00:00    111211
